# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import os
from dotenv import find_dotenv, load_dotenv
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import random
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
load_dotenv(find_dotenv())
# Load the raw data path from environment variable

project_dir = Path().resolve().parents[1]
raw_data_path = os.path.join(project_dir, os.getenv('RAWDATAPATH'))

os.listdir(raw_data_path)
# Out:
# ['ptbdb_normal.csv',
#  'mitbih_test.csv',
#  'ptbdb_abnormal.csv',
#  '.gitkeep',
#  'mitbih_train.csv']

# %%
sfreq = 125
def convert_samples_to_times(samples,sfreq):
    times = 1/sfreq*samples
    return times

# %%
mitbih_train = pd.read_csv(f'{raw_data_path}/mitbih_train.csv', header= None)

# %%
X, y = mitbih_train.iloc[:,:-1], mitbih_train.iloc[:,-1]

# %%
samples = X.columns
times = convert_samples_to_times(samples, sfreq = sfreq)

# %%
fig, ax = plt.subplots(4,5,sharex = True, sharey = True, figsize = [12,8])
for i in range(4):
    for j in range(5):
        X_class = X[y == j]

        idx = random.sample(range(len(X_class)),10)
        ax[i][j].plot(times, X_normal.iloc[idx, :].T)
